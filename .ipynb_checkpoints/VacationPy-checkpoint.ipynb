# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                         City      Lat       Lng  Max Temp  \
# 0        0                        tiksi  71.6872  128.8694      3.58
# 1        1  edinburgh of the seven seas -37.0676  -12.3116     12.86
# 2        2               margaret river -33.9500  115.0667     18.51
# 3        3               saint-philippe -21.3585   55.7679     20.77
# 4        4               port elizabeth -33.9180   25.5701      8.16
#
#    Humidity  Cloudiness  Wind Speed Country        Date
# 0        94          37        8.47      RU  1694475906
# 1        83          76        9.96      SH  1694475915
# 2        74          35        9.25      AU  1694475793
# 3        79          21        2.42      RE  1694475943
# 4        81          20        3.60      ZA  1694475918

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
# Configure the map plot
city_plot = city_data_df.hvplot.points(
    'Lng', 
    'Lat', 
    geo=True, 
    tiles='OSM', 
    size='Humidity', 
    hover_cols=['City', 'Humidity'],
    color='Humidity', 
    colormap='viridis',
    height=500,
    width=900
)

# Display the map
city_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Humidity,City)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_conditions = city_data_df[
    (city_data_df['Max Temp'] >= 20) & 
    (city_data_df['Max Temp'] <= 30) & 
    (city_data_df['Wind Speed'] < 10) & 
    (city_data_df['Cloudiness'] == 0)]

# Drop any rows with null values
ideal_conditions.dropna

# Display sample data
ideal_conditions
# Out:
#      City_ID              City      Lat       Lng  Max Temp  Humidity  \
# 20        20         sandpoint  48.2766 -116.5533     27.14        42
# 43        43         mount isa -20.7333  139.5000     23.87        20
# 48        48           colonia  50.9333    6.9500     21.81        79
# 90        90           emerald -23.5333  148.1667     21.10        42
# 129      129        greenville  35.6127  -77.3663     26.74        84
# 139      139          fukuecho  32.6881  128.8419     26.20        78
# 219      219        siwa oasis  29.2041   25.5195     24.49        68
# 226      226         jamestown  42.0970  -79.2353     21.77        68
# 227      227     marsh harbour  26.5412  -77.0636     28.75        74
# 228      228              tete -16.1564   33.5867     27.05        39
# 244      244            touros  -5.1989  -35.4608     25.25        77
# 266      266          pimentel  -6.8367  -79.9342     23.16        68
# 274      274           awjilah  29.1081   21.2869     22.20        59
# 275      275            trairi  -3.2778  -39.2689     25.76        83
# 314      314  neon karlovasion  37.7903   26.7044     24.39        67
# 356      356   arraial do cabo -22.9661  -42.0278     21.98        88
# 358      358  north battleford  52.7834 -108.2847     21.89        46
# 359      359              kuqa  41.7278   82.9364     22.84        27
# 360      360       nova vicosa -17.8919  -39.3719     22.94        83
# 372      372     fort mcmurray  56.7268 -111.3810     26.77        34
# 398      398   remire-montjoly   4.9167  -52.2667     27.02        89
# 408      408          ghadamis  30.1337    9.5007     27.17        25
# 430      430          dornbirn  47.4167    9.7331     22.42        81
# 457      457             jirja  26.3383   31.8916     29.12        30
# 491      491        pocahontas  36.2615  -90.9712     28.25        57
# 493      493     prince george  53.9166 -122.7530     21.81        46
# 533      533             pisco -13.7000  -76.2167     20.03        73
# 557      557           al jawf  29.5000   38.7500     27.19        28
# 559      559         quelimane -17.8786   36.8883     23.97        88
# 561      561           tsiombe -25.3000   45.4833     21.69        55
# 572      572               mao  39.8885    4.2658     23.31        88
#
#      Cloudiness  Wind Speed Country        Date
# 20            0        2.57      US  1694475789
# 43            0        4.12      AU  1694475954
# 48            0        3.09      DE  1694475658
# 90            0        5.66      AU  1694475965
# 129           0        0.00      US  1694475825
# 139           0        2.06      JP  1694475976
# 219           0        5.57      EG  1694475995
# 226           0        2.57      US  1694475848
# 227           0        5.13      BS  1694475997
# 228           0        0.00      MZ  1694475997
# 244           0        6.72      BR  1694476001
# 266           0        8.23      PE  1694476005
# 274           0        4.92      LY  1694476007
# 275           0        5.58      BR  1694476007
# 314           0        6.16      GR  1694476016
# 356           0        7.20      BR  1694476027
# 358           0        8.75      CA  1694476027
# 359           0        1.19      CN  1694476027
# 360           0        3.58      BR  1694476028
# 372           0        6.69      CA  1694475882
# 398           0        3.09      GF  1694476036
# 408           0        4.73      LY  1694476039
# 430           0        1.03      AT  1694476045
# 457           0        3.09      EG  1694476051
# 491           0        2.06      US  1694475903
# 493           0        2.06      CA  1694476059
# 533           0        7.20      PE  1694475858
# 557           0        3.25      SA  1694476074
# 559           0        4.63      MZ  1694476075
# 561           0        2.40      MG  1694476075
# 572           0        2.57      ES  1694476077

# %%
# Narrow down cities that fit criteria and drop any results with null values
# ideal_conditions = city_data_df[
#     (city_data_df['Max Temp'] < 27) & 
#     (city_data_df['Max Temp'] > 21) & 
#     (city_data_df['Wind Speed'] < 4.5) & 
#     (city_data_df['Cloudiness'] == 0)]

# # Drop any rows with null values
# ideal_conditions.dropna

# Display sample data
# ideal_conditions

# # Narrow down cities that fit criteria and drop any results with null values
# ideal_conditions = city_data_df[
#     (city_data_df['Max Temp'] >= 20) & 
#     (city_data_df['Max Temp'] <= 30) & 
#     (city_data_df['Wind Speed'] < 10) & 
#     (city_data_df['Cloudiness'] == 0)].copy()

# # Drop any rows with null values
# ideal_conditions.dropna(inplace=True)

# # Display sample data
# ideal_conditions.head()

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# Create DataFrame for hotels
hotel_df = ideal_conditions[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add "Hotel Name" column
hotel_df['Hotel Name'] = ""

# Display sample data
hotel_df.head()
# Out:
#            City Country      Lat       Lng  Humidity Hotel Name
# 20    sandpoint      US  48.2766 -116.5533        42
# 43    mount isa      AU -20.7333  139.5000        20
# 48      colonia      DE  50.9333    6.9500        79
# 90      emerald      AU -23.5333  148.1667        42
# 129  greenville      US  35.6127  -77.3663        84

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = "10000"
params = {
    "categories": "accommodation.hotel",
    "apiKey": geoapify_key,
    "type": "hotel",
    "radius": radius,
    "limit": 20
    
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row['Lat']
    lng = row['Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:${lng},${lat},{radius}"
    params["bias"] = f"proximity:${lng},${lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# sandpoint - nearest hotel: No hotel found
# mount isa - nearest hotel: No hotel found
# colonia - nearest hotel: No hotel found
# emerald - nearest hotel: No hotel found
# greenville - nearest hotel: No hotel found
# fukuecho - nearest hotel: No hotel found
# siwa oasis - nearest hotel: No hotel found
# jamestown - nearest hotel: No hotel found
# marsh harbour - nearest hotel: No hotel found
# tete - nearest hotel: No hotel found
# touros - nearest hotel: No hotel found
# pimentel - nearest hotel: No hotel found
# awjilah - nearest hotel: No hotel found
# trairi - nearest hotel: No hotel found
# neon karlovasion - nearest hotel: No hotel found
# arraial do cabo - nearest hotel: No hotel found
# north battleford - nearest hotel: No hotel found
# kuqa - nearest hotel: No hotel found
# nova vicosa - nearest hotel: No hotel found
# fort mcmurray - nearest hotel: No hotel found
# remire-montjoly - nearest hotel: No hotel found
# ghadamis - nearest hotel: No hotel found
# dornbirn - nearest hotel: No hotel found
# jirja - nearest hotel: No hotel found
# pocahontas - nearest hotel: No hotel found
# prince george - nearest hotel: No hotel found
# pisco - nearest hotel: No hotel found
# al jawf - nearest hotel: No hotel found
# quelimane - nearest hotel: No hotel found
# tsiombe - nearest hotel: No hotel found
# mao - nearest hotel: No hotel found
#                  City Country      Lat       Lng  Humidity      Hotel Name
# 20          sandpoint      US  48.2766 -116.5533        42  No hotel found
# 43          mount isa      AU -20.7333  139.5000        20  No hotel found
# 48            colonia      DE  50.9333    6.9500        79  No hotel found
# 90            emerald      AU -23.5333  148.1667        42  No hotel found
# 129        greenville      US  35.6127  -77.3663        84  No hotel found
# 139          fukuecho      JP  32.6881  128.8419        78  No hotel found
# 219        siwa oasis      EG  29.2041   25.5195        68  No hotel found
# 226         jamestown      US  42.0970  -79.2353        68  No hotel found
# 227     marsh harbour      BS  26.5412  -77.0636        74  No hotel found
# 228              tete      MZ -16.1564   33.5867        39  No hotel found
# 244            touros      BR  -5.1989  -35.4608        77  No hotel found
# 266          pimentel      PE  -6.8367  -79.9342        68  No hotel found
# 274           awjilah      LY  29.1081   21.2869        59  No hotel found
# 275            trairi      BR  -3.2778  -39.2689        83  No hotel found
# 314  neon karlovasion      GR  37.7903   26.7044        67  No hotel found
# 356   arraial do cabo      BR -22.9661  -42.0278        88  No hotel found
# 358  north battleford      CA  52.7834 -108.2847        46  No hotel found
# 359              kuqa      CN  41.7278   82.9364        27  No hotel found
# 360       nova vicosa      BR -17.8919  -39.3719        83  No hotel found
# 372     fort mcmurray      CA  56.7268 -111.3810        34  No hotel found
# 398   remire-montjoly      GF   4.9167  -52.2667        89  No hotel found
# 408          ghadamis      LY  30.1337    9.5007        25  No hotel found
# 430          dornbirn      AT  47.4167    9.7331        81  No hotel found
# 457             jirja      EG  26.3383   31.8916        30  No hotel found
# 491        pocahontas      US  36.2615  -90.9712        57  No hotel found
# 493     prince george      CA  53.9166 -122.7530        46  No hotel found
# 533             pisco      PE -13.7000  -76.2167        73  No hotel found
# 557           al jawf      SA  29.5000   38.7500        28  No hotel found
# 559         quelimane      MZ -17.8786   36.8883        88  No hotel found
# 561           tsiombe      MG -25.3000   45.4833        55  No hotel found
# 572               mao      ES  39.8885    4.2658        88  No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_plot = hotel_df.hvplot.points(
    'Lng', 
    'Lat',
    geo=True,
    tiles='OSM',
    hover_cols=['City', 'Country', 'Hotel Name'], 
    color='Humidity', 
    colormap='viridis',
    height=500,
    width=900
)

# Display the map
hotel_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Humidity,City,Country,Hotel Name)
